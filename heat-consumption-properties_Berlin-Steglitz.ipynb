# %% [markdown]
# # Visualization and Exploration of the heat demand in one of Berlins districts

# %% [markdown]
# We are going to use data of Berlins district *Steglitz-Zehlendorf*.
# You find the dataset here:
#
# https://www.govdata.de/web/guest/daten/-/details/energieverbrauch-der-offentlichen-gebaude-2017-bezirk-steglitz-zehlendorf

# %%
import pandas as pd

# %%
url_to_inputfile = "https://www.berlin.de/ba-steglitz-zehlendorf/service/daten/ba-sz-energieverbrauchsuebersicht-2017-2021.csv"

# %% [markdown]
# We will use utf-8 as encoding, even though the input file seems to use different encoding.
# I could not figure out which enconding was used originally.

# %%
df_a = pd.read_csv(url_to_inputfile,
                   sep=';',
                   skiprows=2,
                   encoding='utf-8',
                   encoding_errors='ignore'
                  )

# %%
# Rename columns
rename_cols = {
    'Art der Wrme-versorgung': 'typ_of_heat_generation',  
    'Wrme-verbrauch witterungs-bereinigt [kWh]': 'heat_demand_2017 [kWh]',
    'Unnamed: 6': 'heat_demand_2018 [kWh]',
    'Unnamed: 7': 'heat_demand_2019 [kWh]',
    'Unnamed: 8': 'heat_demand_2020 [kWh]',
    'Unnamed: 9': 'heat_demand_2021 [kWh]'
}

columns_to_drop = [
    'Strom-verbrauch [kWh]', 
    'Unnamed: 11',
    'Unnamed: 12',
    'Unnamed: 13',
    'Unnamed: 14'
]

df_a = df_a \
    .copy() \
    .drop(columns_to_drop, axis=1) \
    .drop([0], axis=0) \
    .rename(columns=rename_cols)

# %% [markdown]
# ### Let's have a look at the (almost raw) data-set before we clean and convert the values

# %%
df_a.style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style type="text/css">
# #T_aab5d_row0_col0, #T_aab5d_row0_col1, #T_aab5d_row0_col2, #T_aab5d_row0_col3, #T_aab5d_row0_col4, #T_aab5d_row0_col5, #T_aab5d_row0_col6, #T_aab5d_row0_col7, #T_aab5d_row0_col8, #T_aab5d_row0_col9, #T_aab5d_row0_col10, #T_aab5d_row1_col0, #T_aab5d_row1_col1, #T_aab5d_row1_col2, #T_aab5d_row1_col3, #T_aab5d_row1_col4, #T_aab5d_row1_col5, #T_aab5d_row1_col6, #T_aab5d_row1_col7, #T_aab5d_row1_col8, #T_aab5d_row1_col9, #T_aab5d_row1_col10, #T_aab5d_row2_col0, #T_aab5d_row2_col1, #T_aab5d_row2_col2, #T_aab5d_row2_col3, #T_aab5d_row2_col4, #T_aab5d_row2_col5, #T_aab5d_row2_col6, #T_aab5d_row2_col7, #T_aab5d_row2_col8, #T_aab5d_row2_col9, #T_aab5d_row2_col10, #T_aab5d_row3_col0, #T_aab5d_row3_col1, #T_aab5d_row3_col2, #T_aab5d_row3_col3, #T_aab5d_row3_col4, #T_aab5d_row3_col5, #T_aab5d_row3_col6, #T_aab5d_row3_col7, #T_aab5d_row3_col8, #T_aab5d_row3_col9, #
row13_col2, #T_aab5d_row13_col3, #T_aab5d_row13_col4, #T_aab5d_row13_col5, #T_aab5d_row13_col6, #T_aab5d_row13_col7, #T_aab5d_row13_col8, #T_aab5d_row13_col9, #T_aab5d_row13_col10, #T_aab5d_row14_col0, #T_aab5d_row14_col1, #T_aab5d_row14_col2, #T_aab5d_row14_col3, #T_aab5d_row14_col4, #T_aab5d_row14_col5, #T_aab5d_row14_col6, #T_aab5d_row14_col7, #T_aab5d_row14_col8, #T_aab5d_row14_col9, #T_aab5d_row14_col10, #T_aab5d_row15_col0, #T_aab5d_row15_col1, #T_aab5d_row15_col2, #T_aab5d_row15_col3, #T_aab5d_row15_col4, #T_aab5d_row15_col5, #T_aab5d_row15_col6, #T_aab5d_row15_col7, #T_aab5d_row15_col8, #T_aab5d_row15_col9, #T_aab5d_row15_col10, #T_aab5d_row16_col0, #T_aab5d_row16_col1, #T_aab5d_row16_col2, #T_aab5d_row16_col3, #T_aab5d_row16_col4, #T_aab5d_row16_col5, #T_aab5d_row16_col6, #T_aab5d_row16_col7, #T_aab5d_row16_col8, #T_aab5d_row16_col9, #T_aab5d_row16_col10, #T_aab5d_row17_col0, #T_aab5d_row17_col1, #T_aab5d_row17_col2, #T_aab5d_row17_col3, #T_aab5d_row17_col4, #T_aab5d_row17_col5, #T_aab5d_row17_col6, #T_aab5d_row17_col7 ...

# %% [markdown]
# ### I'm convinced we can transorm this data-set into useful information
# We can achieve that by curating the data into a form easier to understand.

# %%
# convert column names and format of values
convert_cols = ['heat_demand_2017 [kWh]', 'heat_demand_2018 [kWh]', 'heat_demand_2019 [kWh]', 
               'heat_demand_2020 [kWh]', 'heat_demand_2021 [kWh]']
annual_consumptions_cols = []

df_aa = df_a.copy()
for each_col in convert_cols:
    # remove decimal point '.'
    df_aa[each_col] = df_aa[each_col].apply(lambda x: float(str(x).replace('.','')))
    # convert from kWh to MWh and set correct unit in coloumn names
    new_col_name = each_col.replace('kWh', 'MWh')
    df_aa = df_aa.copy().rename(columns={each_col: new_col_name})
    annual_consumptions_cols.append(new_col_name)
    df_aa[new_col_name] = df_aa[new_col_name].apply(lambda x: x/1000).round()

# %%
# remove some information to focus on the annual heat demand of the properties from 2017 to 2021
df_b = df_aa.drop(['lfd. Nr.', 'Adresse', 'PLZ', 'typ_of_heat_generation', 'Bemerkungen'], axis=1)

# %%
# set min/max for bar-vizualisiation
max_val = df_b['heat_demand_2017 [MWh]'].quantile(.85)
min_val = 0

df_b.style\
    .bar(subset=annual_consumptions_cols,
         align='left', vmin=min_val, vmax=max_val, cmap="bwr",
         height=50, width=60, props="width: 80px; border-right: 1px solid black;")\
    .format(subset=annual_consumptions_cols, precision=0, na_rep='k.A.')
# Out:
# <style type="text/css">
) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row1_col4, #T_9b42e_row13_col1, #T_9b42e_row58_col3, #T_9b42e_row85_col2 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ffdede 34.0%, transparent 34.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row1_col5 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ffcece 35.7%, transparent 35.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row2_col1, #T_9b42e_row114_col4 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff1616 57.2%, transparent 57.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row2_col2 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff2222 55.8%, transparent 55.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row2_col3 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff4c4c 50.9%, transparent 50.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row2_col4, #T_9b42e_row98_col3, #T_9b42e_row112_col1 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff5252 50.2%, transparent 50.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row2_col5, #T_9b42e_row9_col5 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff3e3e 52.6%, transparent 52.6%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row3_col1, #T_9b42e_row18_col2 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ffaaaa 39.9%, transparent 39.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row3_col2 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff8686 44.2%, transparent 44.2%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row3_col3 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ffb2b2 39.1%, transparent 39.1%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row3_col4, #T_9b42e_row18_col5, #T_9b42e_row36_col5 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff9494 42.5%, transparent 42.5%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row3_col5, #T_9b42e_row27_col4 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff5c5c 49.0%, transparent 49.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row4_col1, #T_9b42e_row4_col2, #T_9b42e_row43_col3 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff7878 45.8%, transparent 45.8%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row4_col3, #T_9b42e_row15_col4 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff7676 46.0%, transparent 46.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row4_col4, #T_9b42e_row10_col5 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff9a9a 41.9%, transparent 41.9%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row4_col5, #T_9b42e_row43_col2 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff6e6e 47.0%, transparent 47.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row5_col1 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ff8484 44.4%, transparent 44.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row5_col2, #T_9b42e_row91_col5 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ffb0b0 39.3%, transparent 39.3%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row5_col3, #T_9b42e_row58_col5 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #fff2f2 31.4%, transparent 31.4%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row5_col4 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #fffafa 30.7%, transparent 30.7%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row5_col5, #T_9b42e_row10_col1 {
#   width: 80px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, #ffe6e6 33.0%, transparent 33.0%) no-repeat center;
#   background-size: 100% 50.0%;
# }
# #T_9b42e_row6_col1, #T_9b42e_row6_col2, #T_9b42e_row6_col3, #T_9b42e_row6_col4, #T_9b42e_row6_col5, #T_9b42e_row8_col1, #T_9b42e_row8_col2, #T_9b42e_row8_col3, #T_9b42e_row8_col4, #T_9b42e_row8_col5, #T_9b42e_row9_col1, #T_9b42e_row19_col1, #T_9b42e_row19_col2, #T_9b42e_row19_col3, #T_9b42e_row19_col4, #T_9b42e_row19_col5, #T_9b42e_row22_col2, #T_9b42e_row22_col3, #T_9b42e_row22_col4, #T_9b42e_row25_col1, #T_9b42e_row25_col2, #T_9b42e_row25_col3, #T_9b42e_row25_col4, #T_9b42e_row25_col5, #T_9b42e_row26_col1, #T_9b42e_row26_col3, #T_9b42e_row26_col5, #T_9b42e_row28_col1, #T_9b42e_row28_col2, #T_9b42e_row28_col4, #T_9b42e_row28_col5, #T_9b42e_row30_col1, #T_9b42e_row30_col2, #T_9b42e_row30_col3, #T_9b42e_row30_col4, #T_9b42e_row30_col5, #T_9b42e_row34_col1, #T_9b42e_row34_col2, #T_9b42e_row34_col3, #T_9b42e_row34_co
